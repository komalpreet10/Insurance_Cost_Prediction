# %% [markdown]
# ## Problem Statement
#
# Insurance companies need to accurately predict the cost of health insurance for individuals to set premiums appropriately.
# However, traditional methods of cost prediction often rely on broad actuarial tables and historical averages, which may not account for the nuanced differences among individuals.
#
# By leveraging machine learning techniques, insurers can more accurately predict insurance costs tailored to individual profiles, leading to:
#
# - More competitive pricing
# - Improved risk management
# - Better alignment between premiums and actual health risks

# %% [markdown]
# ## Insurance Cost Prediction Need
#
# The primary need for this project arises from the challenges insurers face in pricing policies accurately while remaining competitive in the market.
# Inaccurate predictions can lead to losses for insurers and unfairly high premiums for policyholders.
#
# By implementing a machine learning model, insurers can:
#
# - **Enhance Precision in Pricing**: Use individual data points to determine premiums that reflect actual risk more closely than generic estimates.
# - **Increase Competitiveness**: Offer rates that are attractive to consumers while ensuring that the pricing is sustainable for the insurer.
# - **Improve Customer Satisfaction**: Fair and transparent pricing based on personal health data can increase trust and satisfaction among policyholders.
# - **Enable Personalized Offerings**: Create customized insurance packages based on predicted costs, catering more directly to individual needs and preferences.
# - **Risk Assessment**: Refine risk assessment processes by identifying key factors that most significantly influence costs.
# - **Policy Development**: Use insights from the model to inform the creation of new insurance products or the adjustment of existing ones.
# - **Strategic Decision Making**: Support broader strategic decisions, such as entering new markets or adjusting policy terms based on risk predictions.
# - **Customer Engagement**: Apply insights from the model in customer engagement initiatives, including personalized marketing and tailored advice for policyholders.

# %% [markdown]
# ## Data Description
#
# The dataset comprises the following 11 attributes:
#
# 1. **Age**: Numeric, ranging from 18 to 66 years.
# 2. **Diabetes**: Binary (0 or 1), where 1 indicates the presence of diabetes.
# 3. **BloodPressureProblems**: Binary (0 or 1), indicating the presence of blood pressure-related issues.
# 4. **AnyTransplants**: Binary (0 or 1), where 1 indicates the person has had a transplant.
# 5. **AnyChronicDiseases**: Binary (0 or 1), indicating the presence of any chronic diseases.
# 6. **Height**: Numeric, measured in centimeters, ranging from 145 cm to 188 cm.
# 7. **Weight**: Numeric, measured in kilograms, ranging from 51 kg to 132 kg.
# 8. **KnownAllergies**: Binary (0 or 1), where 1 indicates known allergies.
# 9. **HistoryOfCancerInFamily**: Binary (0 or 1), indicating a family history of cancer.
# 10. **NumberOfMajorSurgeries**: Numeric, counting the number of major surgeries, ranging from 0 to 3 surgeries.
# 11. **PremiumPrice**: Numeric, representing the premium price in currency, ranging from 15,000 to 40,000.

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ttest_ind
from scipy.stats import f_oneway
from scipy.stats import chi2_contingency
from sklearn.linear_model import LinearRegression
from sklearn import tree
from sklearn.tree import plot_tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
# importing the dataset
df = pd.read_csv('insurance.csv')

# %%
df.head()
# Out:
#    Age  Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# 0   45         0                      0               0                   0
# 1   60         1                      0               0                   0
# 2   36         1                      1               0                   0
# 3   52         1                      1               0                   1
# 4   38         0                      0               0                   1
#
#    Height  Weight  KnownAllergies  HistoryOfCancerInFamily  \
# 0     155      57               0                        0
# 1     180      73               0                        0
# 2     158      59               0                        0
# 3     183      93               0                        0
# 4     166      88               0                        0
#
#    NumberOfMajorSurgeries  PremiumPrice
# 0                       0         25000
# 1                       0         29000
# ...

# %% [markdown]
# # EDA and Hypothesis Testing

# %%
df.shape
# Out:
# (986, 11)

# %% [markdown]
# # Insights:
#
# The dataset contains information about 986 insurers and 11 attributes realted to health and demographic factors. These attributes cover various health conditions, medical history, and basic physical measurements. The data provides a comprehensive overview that can be analyzed to understand patterns and correlations affecting health insurance premiums.

# %%
df.columns
# Out:
# Index(['Age', 'Diabetes', 'BloodPressureProblems', 'AnyTransplants',
#        'AnyChronicDiseases', 'Height', 'Weight', 'KnownAllergies',
#        'HistoryOfCancerInFamily', 'NumberOfMajorSurgeries', 'PremiumPrice'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      986 non-null    int64
#  1   Diabetes                 986 non-null    int64
#  2   BloodPressureProblems    986 non-null    int64
#  3   AnyTransplants           986 non-null    int64
#  4   AnyChronicDiseases       986 non-null    int64
#  5   Height                   986 non-null    int64
#  6   Weight                   986 non-null    int64
#  7   KnownAllergies           986 non-null    int64
#  8   HistoryOfCancerInFamily  986 non-null    int64
#  9   NumberOfMajorSurgeries   986 non-null    int64
#  10  PremiumPrice             986 non-null    int64
# dtypes: int64(11)
# memory usage: 84.9 KB

# %%
columns = ['Diabetes', 'BloodPressureProblems', 'AnyTransplants','AnyChronicDiseases', 'KnownAllergies','HistoryOfCancerInFamily', 'NumberOfMajorSurgeries']

# %%
for i in range(0, len(columns)):
    df[columns[i]] = df[columns[i]].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      986 non-null    int64
#  1   Diabetes                 986 non-null    category
#  2   BloodPressureProblems    986 non-null    category
#  3   AnyTransplants           986 non-null    category
#  4   AnyChronicDiseases       986 non-null    category
#  5   Height                   986 non-null    int64
#  6   Weight                   986 non-null    int64
#  7   KnownAllergies           986 non-null    category
#  8   HistoryOfCancerInFamily  986 non-null    category
#  9   NumberOfMajorSurgeries   986 non-null    category
#  10  PremiumPrice             986 non-null    int64
# dtypes: category(7), int64(4)
# memory usage: 38.6 KB

# %%
df.describe()
# Out:
#               Age      Height      Weight  PremiumPrice
# count  986.000000  986.000000  986.000000    986.000000
# mean    41.745436  168.182556   76.950304  24336.713996
# std     13.963371   10.098155   14.265096   6248.184382
# min     18.000000  145.000000   51.000000  15000.000000
# 25%     30.000000  161.000000   67.000000  21000.000000
# 50%     42.000000  168.000000   75.000000  23000.000000
# 75%     53.000000  176.000000   87.000000  28000.000000
# max     66.000000  188.000000  132.000000  40000.000000

# %% [markdown]
# ## Insights from Summary Statistics
#
# The dataset contains **986 customers**. Key observations are:
#
# - **Age**
#   - Range: **18 to 66 years**
#   - Average age: **~42 years**
#   - 50% of customers are between **30 and 53 years**
#
# - **Height & Weight**
#   - Average height: **168 cm** (range: 145–188 cm)
#   - Average weight: **77 kg** (range: 51–132 kg)
#   - Most customers weigh between **67 and 87 kg**
#
# - **Premium Prices**
#   - Range: **15,000 to 40,000**
#   - Average premium: **~24,337**
#   - 50% of customers pay between **21,000 and 28,000**
#   - Customers with premiums closer to **40,000** may represent **high-risk individuals** (older age, higher BMI, chronic conditions)

# %%
df.describe(include = 'category')
# Out:
#         Diabetes  BloodPressureProblems  AnyTransplants  AnyChronicDiseases  \
# count        986                    986             986                 986
# unique         2                      2               2                   2
# top            0                      0               0                   0
# freq         572                    524             931                 808
#
#         KnownAllergies  HistoryOfCancerInFamily  NumberOfMajorSurgeries
# count              986                      986                     986
# unique               2                        2                       4
# top                  0                        0                       0
# freq               774                      870                     479

# %% [markdown]
# ## Insights from Categorical Features
#
# The dataset also includes several **medical history features** for 986 customers:
#
# - **Diabetes**
#   - 572 customers (58%) do **not** have diabetes.
#   - Remaining 414 (42%) have diabetes.
#
# - **Blood Pressure Problems**
#   - 524 customers (53%) do **not** have blood pressure problems.
#   - 462 (47%) have blood pressure problems.
#
# - **Transplants**
#   - Vast majority (931 customers, 94%) have **no history of transplants**.
#
# - **Chronic Diseases**
#   - 808 customers (82%) report **no chronic diseases**.
#   - 178 (18%) have at least one chronic condition.
#
# - **Known Allergies**
#   - 774 customers (79%) report **no known allergies**.
#   - 212 (21%) have allergies.
#
# - **Family History of Cancer**
#   - 870 customers (88%) have **no family history of cancer**.
#   - 116 (12%) do.
#
# - **Number of Major Surgeries**
#   - Most customers (479, 49%) have had **no major surgeries**.
#   - The rest are spread across 1–3 surgeries.
#
# ---
#
# **Overall Insight:**
# Most customers are **healthy** with no transplants, no chronic diseases, no allergies, and no family history of cancer. However, a **significant proportion** of customers (about 40–45%) report diabetes or blood pressure problems, which likely contributes to higher premium costs.

# %%
df.isnull().sum()
# Out:
# Age                        0
# Diabetes                   0
# BloodPressureProblems      0
# AnyTransplants             0
# AnyChronicDiseases         0
# Height                     0
# Weight                     0
# KnownAllergies             0
# HistoryOfCancerInFamily    0
# NumberOfMajorSurgeries     0
# PremiumPrice               0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# The dataset has no missing values and no duplicate rows.

# %% [markdown]
# ## Distribution Analysis

# %%
numeric_cols = ['Age', 'Height', 'Weight','PremiumPrice']

for col in numeric_cols:
    sns.histplot(df[col], kde = True)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# %% [markdown]
# ## Distribution Analysis
#
# - **Age:** The distribution is fairly symmetric, centered around the early 40s, with most individuals falling in the 30–53 range, suggesting a balanced middle-aged population.
# - **Height:** Heights follow an approximately normal distribution around 168 cm, with little skewness, indicating no extreme variations in body stature.
# - **Weight:** The distribution is slightly right-skewed, as most people weigh 67–87 kg but some outliers extend up to 132 kg.
# - **Premium Price:** Premium prices are moderately right-skewed, with the bulk of values between 21,000–28,000, but a few high-cost outliers raise the maximum to 40,000.

# %%
df[ 'Diabetes'].value_counts()/len(df) *100
# Out:
# Diabetes
# 0    58.01217
# 1    41.98783
# Name: count, dtype: float64

# %%
df['BloodPressureProblems'].value_counts()/len(df) *100
# Out:
# BloodPressureProblems
# 0    53.144016
# 1    46.855984
# Name: count, dtype: float64

# %%
df['AnyTransplants'].value_counts()/len(df) *100
# Out:
# AnyTransplants
# 0    94.421907
# 1     5.578093
# Name: count, dtype: float64

# %%
df['AnyChronicDiseases'].value_counts()/len(df) *100
# Out:
# AnyChronicDiseases
# 0    81.947262
# 1    18.052738
# Name: count, dtype: float64

# %%
df['KnownAllergies'].value_counts()/len(df) *100
# Out:
# KnownAllergies
# 0    78.498986
# 1    21.501014
# Name: count, dtype: float64

# %%
df['HistoryOfCancerInFamily'].value_counts()/len(df) *100
# Out:
# HistoryOfCancerInFamily
# 0    88.235294
# 1    11.764706
# Name: count, dtype: float64

# %%
df['NumberOfMajorSurgeries'].value_counts()/len(df) *100
# Out:
# NumberOfMajorSurgeries
# 0    48.580122
# 1    37.728195
# 2    12.068966
# 3     1.622718
# Name: count, dtype: float64

# %%
binary_cols = [
    'Diabetes', 'BloodPressureProblems', 'AnyTransplants',
    'AnyChronicDiseases', 'KnownAllergies', 'HistoryOfCancerInFamily','NumberOfMajorSurgeries'
]

for col in binary_cols:
    sns.countplot(x=col, data=df)
    plt.title(f"Count of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# %% [markdown]
# - **Diabetes:** About 58% of individuals are non-diabetic while 42% are diabetic, showing a fairly balanced distribution useful for cost comparison.
# - **Blood Pressure Problems:** Around 53% do not have blood pressure problems and 47% do, indicating a nearly even split between the groups.
# - **Any Transplants:** A large majority (94%) have not undergone transplants, while only about 6% have, suggesting transplant cases are relatively rare.
# - **Any Chronic Diseases:** Roughly 82% of individuals report no chronic diseases, while 18% do, highlighting a smaller but significant segment with chronic health issues.
# - **Known Allergies:** About 78% of individuals have no known allergies, while 22% do, indicating allergies are relatively common in the population.
# - **History of Cancer in Family:** Nearly 88% report no family history of cancer, while 12% do, showing a smaller subset with genetic risk factors.
# - **Number of Major Surgeries:** Almost 49% of individuals have had no major surgeries, 38% had one, 12% had two, and about 2% had three, reflecting that most people fall into the 0–1 surgeries range.

# %% [markdown]
# ## Bivariate Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      986 non-null    int64
#  1   Diabetes                 986 non-null    category
#  2   BloodPressureProblems    986 non-null    category
#  3   AnyTransplants           986 non-null    category
#  4   AnyChronicDiseases       986 non-null    category
#  5   Height                   986 non-null    int64
#  6   Weight                   986 non-null    int64
#  7   KnownAllergies           986 non-null    category
#  8   HistoryOfCancerInFamily  986 non-null    category
#  9   NumberOfMajorSurgeries   986 non-null    category
#  10  PremiumPrice             986 non-null    int64
# dtypes: category(7), int64(4)
# memory usage: 38.6 KB

# %%
num_df = df.select_dtypes(include=['int64', 'float64'])
corr = num_df.corr()
corr
# Out:
#                    Age    Height    Weight  PremiumPrice
# Age           1.000000  0.039879 -0.018590      0.697540
# Height        0.039879  1.000000  0.066946      0.026910
# Weight       -0.018590  0.066946  1.000000      0.141507
# PremiumPrice  0.697540  0.026910  0.141507      1.000000

# %%
sns.scatterplot(data=df, x="Age", y="PremiumPrice")

plt.show()

# %%
sns.scatterplot(data=df, x="Height", y="PremiumPrice")

plt.show()

# %%
sns.scatterplot(data=df, x="Weight", y="PremiumPrice")

plt.show()

# %%
sns.scatterplot(data=df, x="Age", y="Height")

plt.show()

# %%
sns.scatterplot(data=df, x="Age", y="Weight")

plt.show()

# %%
sns.scatterplot(data=df, x="Height", y="Weight")

plt.show()

# %% [markdown]
# - **Age vs Premium Price:** The scatter plot shows a clear upward trend, with points clustering along a rising line — older individuals generally pay higher premiums.
# - **Height vs Premium Price:** The scatter plot looks like a random cloud of points, with no visible pattern — height does not influence premium prices.
# - **Weight vs Premium Price:** The scatter plot shows a slightly upward but widely scattered pattern — heavier individuals may pay marginally higher premiums, but the effect is weak.
# - **Age vs Height:** The scatter plot looks very scattered with no trend — age and height appear unrelated.
# - **Age vs Weight:** The scatter plot looks like a random spread of points — weight does not vary systematically with age.
# - **Height vs Weight:** The scatter plot shows a faint upward trend, but still quite scattered — taller individuals are somewhat heavier, though the relationship is weak.

# %%
df.groupby('Diabetes')['PremiumPrice'].describe()
# Out:
# /var/folders/tr/48b5vkj546x40jc58hfctl6h0000gn/T/ipykernel_63011/4194353552.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Diabetes')['PremiumPrice'].describe()
#           count          mean          std      min      25%      50%  \
# Diabetes
# 0         572.0  23931.818182  6562.956719  15000.0  19000.0  23000.0
# 1         414.0  24896.135266  5746.150162  15000.0  23000.0  25000.0
#
#               75%      max
# Diabetes
# 0         29000.0  39000.0
# 1         28000.0  40000.0

# %%
df.groupby('BloodPressureProblems')['PremiumPrice'].describe()
# Out:
# /var/folders/tr/48b5vkj546x40jc58hfctl6h0000gn/T/ipykernel_63011/1909706941.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('BloodPressureProblems')['PremiumPrice'].describe()
#                        count          mean          std      min      25%  \
# BloodPressureProblems
# 0                      524.0  23356.870229  6605.847295  15000.0  15000.0
# 1                      462.0  25448.051948  5619.584064  15000.0  23000.0
#
#                            50%      75%      max
# BloodPressureProblems
# 0                      23000.0  28000.0  39000.0
# 1                      25000.0  28000.0  40000.0

# %%
df.groupby('AnyTransplants')['PremiumPrice'].describe()
# Out:
# /var/folders/tr/48b5vkj546x40jc58hfctl6h0000gn/T/ipykernel_63011/303276455.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('AnyTransplants')['PremiumPrice'].describe()
#                 count          mean          std      min      25%      50%  \
# AnyTransplants
# 0               931.0  23897.959184  5741.502007  15000.0  21000.0  23000.0
# 1                55.0  31763.636364  9213.443552  15000.0  28000.0  38000.0
#
#                     75%      max
# AnyTransplants
# 0               28000.0  40000.0
# 1               38000.0  38000.0

# %%
df.groupby('AnyChronicDiseases')['PremiumPrice'].describe()
# Out:
# /var/folders/tr/48b5vkj546x40jc58hfctl6h0000gn/T/ipykernel_63011/63296957.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('AnyChronicDiseases')['PremiumPrice'].describe()
#                     count          mean          std      min      25%  \
# AnyChronicDiseases
# 0                   808.0  23725.247525  6322.106231  15000.0  15750.0
# 1                   178.0  27112.359551  5056.602111  18000.0  23000.0
#
#                         50%      75%      max
# AnyChronicDiseases
# 0                   23000.0  28000.0  39000.0
# 1                   28000.0  30000.0  40000.0

# %%
df.groupby('KnownAllergies')['PremiumPrice'].describe()
# Out:
# /var/folders/tr/48b5vkj546x40jc58hfctl6h0000gn/T/ipykernel_63011/1937799108.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('KnownAllergies')['PremiumPrice'].describe()
#                 count          mean          std      min      25%      50%  \
# KnownAllergies
# 0               774.0  24297.157623  6165.636707  15000.0  21000.0  23000.0
# 1               212.0  24481.132075  6553.796529  15000.0  21000.0  23000.0
#
#                     75%      max
# KnownAllergies
# 0               28000.0  40000.0
# 1               29000.0  39000.0

# %%
df.groupby('HistoryOfCancerInFamily')['PremiumPrice'].describe()
# Out:
# /var/folders/tr/48b5vkj546x40jc58hfctl6h0000gn/T/ipykernel_63011/2416606355.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('HistoryOfCancerInFamily')['PremiumPrice'].describe()
#                          count          mean          std      min      25%  \
# HistoryOfCancerInFamily
# 0                        870.0  24147.126437  6117.864935  15000.0  21500.0
# 1                        116.0  25758.620690  7017.519306  15000.0  21000.0
#
#                              50%      75%      max
# HistoryOfCancerInFamily
# 0                        23000.0  28000.0  40000.0
# 1                        28000.0  31000.0  39000.0

# %%
df.groupby('NumberOfMajorSurgeries')['PremiumPrice'].describe()
# Out:
# /var/folders/tr/48b5vkj546x40jc58hfctl6h0000gn/T/ipykernel_63011/3893770278.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('NumberOfMajorSurgeries')['PremiumPrice'].describe()
#                         count          mean          std      min      25%  \
# NumberOfMajorSurgeries
# 0                       479.0  22968.684760  6356.976577  15000.0  15000.0
# 1                       372.0  24741.935484  6593.966409  15000.0  21000.0
# 2                       119.0  28084.033613  1175.886481  24000.0  28000.0
# 3                        16.0  28000.000000     0.000000  28000.0  28000.0
#
#                             50%      75%      max
# NumberOfMajorSurgeries
# 0                       23000.0  25000.0  39000.0
# 1                       25000.0  29250.0  39000.0
# ...

# %%
sns.boxplot(x='Diabetes', y='PremiumPrice', data=df)
plt.title("PremiumPrice by Diabetes")
plt.show()

# %%
sns.boxplot(x='BloodPressureProblems', y='PremiumPrice', data=df)
plt.title("PremiumPrice by BloodPressureProblems")
plt.show()

# %% [markdown]
# ### Categorical Feature Insights
#
# - Customers with diabetes pay higher premiums on average (~24,896) compared to those without (~23,932).
# - Customers with blood pressure problems pay higher premiums on average (~25,448) than those without (~23,357).
# - Customers with a history of transplants have much higher average premiums (~31,764) compared to those without (~23,898).
# - Customers with chronic diseases have higher average premiums (~27,112) than those without (~23,725).
# - Customers with known allergies have slightly higher average premiums (~24,481) compared to those without (~24,297).
# - Customers with a family history of cancer have higher average premiums (~25,759) than those without (~24,147).
# - Average premiums increase with the number of major surgeries, from ~22,969 (no surgeries) to ~28,000 (three surgeries).

# %% [markdown]
# # Correlation Analysis

# %%
corr
# Out:
#                    Age    Height    Weight  PremiumPrice
# Age           1.000000  0.039879 -0.018590      0.697540
# Height        0.039879  1.000000  0.066946      0.026910
# Weight       -0.018590  0.066946  1.000000      0.141507
# PremiumPrice  0.697540  0.026910  0.141507      1.000000

# %%
sns.heatmap(corr, annot = True)
plt.show()

# %% [markdown]
# ### Correlation Insights
#
# - **Age has a strong positive correlation with Premium Price (0.70)**, indicating that older individuals tend to pay significantly higher premiums.
# - **Weight shows a weak positive correlation with Premium Price (0.14)**, suggesting that heavier individuals pay slightly more, but the effect is minimal.
# - **Height has almost no correlation with Premium Price (0.03)**, meaning height does not meaningfully affect insurance costs.
# - **Height and Weight have a weak positive relationship (0.07)**, showing that taller people are only slightly heavier on average.
# - **Age and Weight (-0.02) and Age and Height (0.04)** exhibit negligible relationships, suggesting age is independent of height and weight in this dataset.
#
# **Key Insight:** Among the numerical variables, **Age is the strongest predictor of Premium Price**, while Height and Weight contribute very little.

# %% [markdown]
# # Outlier Detection

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

for col in numeric_cols:
    plt.figure(figsize=(6,3))
    sns.boxplot(x=df[col])
    plt.title(f"Outlier Check for {col}")
    plt.show()

# %%
# Dictionary to store outlier info
outliers_info = {}

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3- Q1
    # Define outlier bounds
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    #Identify outliers
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)][col]
    outliers_info[col] = {'count': outliers.shape[0],
                          'lower_bound': lower_bound,
                          'upper_bound': upper_bound,
                          'outliers': outliers.values}

# Display summary of outliers
for col, info in outliers_info.items():
    print(f"{col}: {info['count']} outliers | Lower Bound: {info['lower_bound']} | Upper Bound: {info['upper_bound']}")
# Out:
# Age: 0 outliers | Lower Bound: -4.5 | Upper Bound: 87.5
# Height: 0 outliers | Lower Bound: 138.5 | Upper Bound: 198.5
# Weight: 16 outliers | Lower Bound: 37.0 | Upper Bound: 117.0
# PremiumPrice: 6 outliers | Lower Bound: 10500.0 | Upper Bound: 38500.0

# %%
# Capping function using IQR bounds
def cap_outliers(col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    df[col] = df[col].apply(lambda x: upper_bound if x > upper_bound else (lower_bound if x < lower_bound else x))

# Apply capping to Weight and PremiumPrice
cap_outliers('Weight')
cap_outliers('PremiumPrice')

# Check after capping
df[['Weight', 'PremiumPrice']].describe()
# Out:
#            Weight  PremiumPrice
# count  986.000000    986.000000
# mean    76.844828  24332.657201
# std     13.930256   6238.686283
# min     51.000000  15000.000000
# 25%     67.000000  21000.000000
# 50%     75.000000  23000.000000
# 75%     87.000000  28000.000000
# max    117.000000  38500.000000

# %% [markdown]
# ## Hypothesis Testing

# %% [markdown]
# ## T-Test Analysis Plan
#
# In this analysis, I will perform **independent two-sample t-tests** (Welch’s t-test) to compare the mean `PremiumPrice` across groups defined by each binary health-related variable in the dataset.
# The variables to be tested include:
#
# - **Diabetes** (0 = No, 1 = Yes)
# - **BloodPressureProblems** (0 = No, 1 = Yes)
# - **AnyTransplants** (0 = No, 1 = Yes)
# - **AnyChronicDiseases** (0 = No, 1 = Yes)
# - **KnownAllergies** (0 = No, 1 = Yes)
# - **HistoryOfCancerInFamily** (0 = No, 1 = Yes)
#
# For each variable:
#
# - **Null Hypothesis (H₀):** There is no significant difference in mean `PremiumPrice` between the two groups.
# - **Alternative Hypothesis (H₁):** There is a significant difference in mean `PremiumPrice` between the two groups.
#
# The test will be performed using a significance level of **α = 0.05**.
# A p-value below 0.05 will indicate that the difference in means is **statistically significant**.
#
# ---

# %%
t_test_columns = ['Diabetes','BloodPressureProblems','AnyTransplants','AnyChronicDiseases','KnownAllergies','HistoryOfCancerInFamily']

# %%
# Loop through all binary variables
for col in t_test_columns:
    # Split data into two groups
    group0 = df[df[col] == 0]['PremiumPrice']
    group1 = df[df[col] == 1]['PremiumPrice']
    
    # Perform Welch's t-test
    t_stat, p_val = ttest_ind(group0, group1, equal_var=False)
    
    # Calculate means for clarity
    mean0 = group0.mean()
    mean1 = group1.mean()
    
    # Print results in a formatted way
    print(f"Variable: {col}")
    print(f"  Mean (0): {mean0:.2f}")
    print(f"  Mean (1): {mean1:.2f}")
    print(f"  T-statistic: {t_stat:.3f}")
    print(f"  P-value for {col}: {p_val:.4f}")  # variable name included here
    
    # Decision rule
    alpha = 0.05
    if p_val < alpha:
        print(f"  → Reject H0: Significant difference exists for {col}.\n")
    else:
        print(f"  → Fail to reject H0: No significant difference for {col}.\n")
# Out:
# Variable: Diabetes
#   Mean (0): 23928.32
#   Mean (1): 24891.30
#   T-statistic: -2.450
#   P-value for Diabetes: 0.0145
#   → Reject H0: Significant difference exists for Diabetes.
#
# Variable: BloodPressureProblems
#   Mean (0): 23355.92
#   Mean (1): 25440.48
#   T-statistic: -5.362
#   P-value for BloodPressureProblems: 0.0000
#   → Reject H0: Significant difference exists for BloodPressureProblems.
#
# Variable: AnyTransplants
#   Mean (0): 23893.66
#   Mean (1): 31763.64
#   T-statistic: -6.264
#   P-value for AnyTransplants: 0.0000
#   → Reject H0: Significant difference exists for AnyTransplants.
#
# Variable: AnyChronicDiseases
#   Mean (0): 23722.15
#   Mean (1): 27103.93
#   T-statistic: -7.721
#   P-value for AnyChronicDiseases: 0.0000
#   → Reject H0: Significant difference exists for AnyChronicDiseases.
#
# Variable: KnownAllergies
#   Mean (0): 24293.28
#   Mean (1): 24476.42
#   T-statistic: -0.366
#   P-value for KnownAllergies: 0.7149
# ...

# %% [markdown]
# # ANOVA

# %%
# Null and Alternative Hypotheses:
# H0: The mean PremiumPrice is the same across all groups of NumberOfMajorSurgeries.
# H1: At least one group has a different mean PremiumPrice.

# Assuming your dataframe is called df
group0 = df[df['NumberOfMajorSurgeries'] == 0]['PremiumPrice']
group1 = df[df['NumberOfMajorSurgeries'] == 1]['PremiumPrice']
group2 = df[df['NumberOfMajorSurgeries'] == 2]['PremiumPrice']
group3 = df[df['NumberOfMajorSurgeries'] == 3]['PremiumPrice']

# Perform ANOVA
f_stat, p_val = f_oneway(group0, group1, group2, group3)

print("F-statistic:", f_stat)
print("P-value:", p_val)

# Decision
if p_val < 0.05:
    print("Reject H0: Significant difference exists between groups.")
else:
    print("Fail to reject H0: No significant difference between groups.")
# Out:
# F-statistic: 26.12471182776423
# P-value: 2.913546650593217e-16
# Reject H0: Significant difference exists between groups.

# %% [markdown]
# ### Hypothesis Testing Insights
#
# - **Diabetes:** Significant difference in premiums (p = 0.0145); customers with diabetes pay higher premiums.
# - **Blood Pressure Problems:** Significant difference (p < 0.001); customers with blood pressure problems pay higher premiums.
# - **Any Transplants:** Significant difference (p < 0.001); customers with a history of transplants pay much higher premiums.
# - **Any Chronic Diseases:** Significant difference (p < 0.001); customers with chronic diseases pay higher premiums.
# - **Known Allergies:** No significant difference (p = 0.715); allergies do not affect premium significantly.
# - **History of Cancer in Family:** Significant difference (p = 0.020); customers with family history of cancer pay higher premiums.
# - **Number of Major Surgeries:** Significant difference in premiums across groups (p < 0.001); premiums increase with more surgeries.

# %% [markdown]
# # Chi-square tests

# %% [markdown]
# ### Chi-Square Test Hypotheses for Categorical Variables
#
# - **Diabetes vs Blood Pressure Problems**
#   - H0: Diabetes and Blood Pressure Problems are independent.
#   - H1: Diabetes and Blood Pressure Problems are dependent.
#
# - **Diabetes vs Any Transplants**
#   - H0: Diabetes and Any Transplants are independent.
#   - H1: Diabetes and Any Transplants are dependent.
#
# - **Diabetes vs Any Chronic Diseases**
#   - H0: Diabetes and Any Chronic Diseases are independent.
#   - H1: Diabetes and Any Chronic Diseases are dependent.
#
# - **Diabetes vs Known Allergies**
#   - H0: Diabetes and Known Allergies are independent.
#   - H1: Diabetes and Known Allergies are dependent.
#
# - **Diabetes vs History of Cancer in Family**
#   - H0: Diabetes and History of Cancer in Family are independent.
#   - H1: Diabetes and History of Cancer in Family are dependent.
#
# - **Diabetes vs Number of Major Surgeries**
#   - H0: Diabetes and Number of Major Surgeries are independent.
#   - H1: Diabetes and Number of Major Surgeries are dependent.
#
# - **Blood Pressure Problems vs Any Transplants**
#   - H0: Blood Pressure Problems and Any Transplants are independent.
#   - H1: Blood Pressure Problems and Any Transplants are dependent.
#
# - **Blood Pressure Problems vs Any Chronic Diseases**
#   - H0: Blood Pressure Problems and Any Chronic Diseases are independent.
#   - H1: Blood Pressure Problems and Any Chronic Diseases are dependent.
#
# - **Blood Pressure Problems vs Known Allergies**
#   - H0: Blood Pressure Problems and Known Allergies are independent.
#   - H1: Blood Pressure Problems and Known Allergies are dependent.
#
# - **Blood Pressure Problems vs History of Cancer in Family**
#   - H0: Blood Pressure Problems and History of Cancer in Family are independent.
#   - H1: Blood Pressure Problems and History of Cancer in Family are dependent.
#
# - **Blood Pressure Problems vs Number of Major Surgeries**
#   - H0: Blood Pressure Problems and Number of Major Surgeries are independent.
#   - H1: Blood Pressure Problems and Number of Major Surgeries are dependent.
#
# - **Any Transplants vs Any Chronic Diseases**
#   - H0: Any Transplants and Any Chronic Diseases are independent.
#   - H1: Any Transplants and Any Chronic Diseases are dependent.
#
# - **Any Transplants vs Known Allergies**
#   - H0: Any Transplants and Known Allergies are independent.
#   - H1: Any Transplants and Known Allergies are dependent.
#
# - **Any Transplants vs History of Cancer in Family**
#   - H0: Any Transplants and History of Cancer in Family are independent.
#   - H1: Any Transplants and History of Cancer in Family are dependent.
#
# - **Any Transplants vs Number of Major Surgeries**
#   - H0: Any Transplants and Number of Major Surgeries are independent.
#   - H1: Any Transplants and Number of Major Surgeries are dependent.
#
# - **Any Chronic Diseases vs Known Allergies**
#   - H0: Any Chronic Diseases and Known Allergies are independent.
#   - H1: Any Chronic Diseases and Known Allergies are dependent.
#
# - **Any Chronic Diseases vs History of Cancer in Family**
#   - H0: Any Chronic Diseases and History of Cancer in Family are independent.
#   - H1: Any Chronic Diseases and History of Cancer in Family are dependent.
#
# - **Any Chronic Diseases vs Number of Major Surgeries**
#   - H0: Any Chronic Diseases and Number of Major Surgeries are independent.
#   - H1: Any Chronic Diseases and Number of Major Surgeries are dependent.
#
# - **Known Allergies vs History of Cancer in Family**
#   - H0: Known Allergies and History of Cancer in Family are independent.
#   - H1: Known Allergies and History of Cancer in Family are dependent.
#
# - **Known Allergies vs Number of Major Surgeries**
#   - H0: Known Allergies and Number of Major Surgeries are independent.
#   - H1: Known Allergies and Number of Major Surgeries are dependent.
#
# - **History of Cancer in Family vs Number of Major Surgeries**
#   - H0: History of Cancer in Family and Number of Major Surgeries are independent.
#   - H1: History of Cancer in Family and Number of Major Surgeries are dependent.

# %%
from itertools import combinations

# List of categorical variables
cat_vars = ['Diabetes', 'BloodPressureProblems', 'AnyTransplants',
            'AnyChronicDiseases', 'KnownAllergies', 'HistoryOfCancerInFamily',
            'NumberOfMajorSurgeries']

# Loop through all pairs
for var1, var2 in combinations(cat_vars, 2):
    # Contingency table
    table = pd.crosstab(df[var1], df[var2])
    
    # Chi-square test
    chi2, p, dof, expected = chi2_contingency(table)
    
    # Print results
    print(f"Chi-square Test: {var1} vs {var2}")
    print(f"Chi2 Statistic: {chi2:.3f}, p-value: {p:.4f}, Degrees of Freedom: {dof}")
    
    # Decision
    alpha = 0.05
    if p < alpha:
        print(f"→ Reject H0: {var1} and {var2} are dependent.\n")
    else:
        print(f"→ Fail to reject H0: {var1} and {var2} are independent.\n")
# Out:
# Chi-square Test: Diabetes vs BloodPressureProblems
# Chi2 Statistic: 15.571, p-value: 0.0001, Degrees of Freedom: 1
# → Reject H0: Diabetes and BloodPressureProblems are dependent.
#
# Chi-square Test: Diabetes vs AnyTransplants
# Chi2 Statistic: 1.021, p-value: 0.3123, Degrees of Freedom: 1
# → Fail to reject H0: Diabetes and AnyTransplants are independent.
#
# Chi-square Test: Diabetes vs AnyChronicDiseases
# Chi2 Statistic: 7.421, p-value: 0.0064, Degrees of Freedom: 1
# → Reject H0: Diabetes and AnyChronicDiseases are dependent.
#
# Chi-square Test: Diabetes vs KnownAllergies
# Chi2 Statistic: 5.938, p-value: 0.0148, Degrees of Freedom: 1
# → Reject H0: Diabetes and KnownAllergies are dependent.
#
# Chi-square Test: Diabetes vs HistoryOfCancerInFamily
# Chi2 Statistic: 2.701, p-value: 0.1003, Degrees of Freedom: 1
# → Fail to reject H0: Diabetes and HistoryOfCancerInFamily are independent.
#
# Chi-square Test: Diabetes vs NumberOfMajorSurgeries
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      986 non-null    int64
#  1   Diabetes                 986 non-null    category
#  2   BloodPressureProblems    986 non-null    category
#  3   AnyTransplants           986 non-null    category
#  4   AnyChronicDiseases       986 non-null    category
#  5   Height                   986 non-null    int64
#  6   Weight                   986 non-null    float64
#  7   KnownAllergies           986 non-null    category
#  8   HistoryOfCancerInFamily  986 non-null    category
#  9   NumberOfMajorSurgeries   986 non-null    category
#  10  PremiumPrice             986 non-null    float64
# dtypes: category(7), float64(2), int64(2)
# memory usage: 38.6 KB

# %% [markdown]
# # ML Modeling

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Feature Engineering

# %%
# Create BMI feature
# Height is in cm, so convert to meters
df['Height_m'] = df['Height'] / 100

# BMI formula: weight (kg) / (height (m))^2
df['BMI'] = df['Weight'] / (df['Height_m'] ** 2)

# Optional: drop temporary column if you don't need it
df.drop(columns=['Height_m'], inplace=True)

# Check the first few rows
df[['Height', 'Weight', 'BMI']].head()
# Out:
#    Height  Weight        BMI
# 0     155    57.0  23.725286
# 1     180    73.0  22.530864
# 2     158    59.0  23.634033
# 3     183    93.0  27.770313
# 4     166    88.0  31.934969

# %%
# One-hot encode NumberOfMajorSurgeries
df= pd.get_dummies(df, columns=['NumberOfMajorSurgeries'], drop_first=True)

# %%
df.head()
# Out:
#    Age Diabetes BloodPressureProblems AnyTransplants AnyChronicDiseases  \
# 0   45        0                     0              0                  0
# 1   60        1                     0              0                  0
# 2   36        1                     1              0                  0
# 3   52        1                     1              0                  1
# 4   38        0                     0              0                  1
#
#    Height  Weight KnownAllergies HistoryOfCancerInFamily  PremiumPrice  \
# 0     155    57.0              0                       0       25000.0
# 1     180    73.0              0                       0       29000.0
# 2     158    59.0              0                       0       23000.0
# 3     183    93.0              0                       0       28000.0
# 4     166    88.0              0                       0       23000.0
#
#          BMI  NumberOfMajorSurgeries_1  NumberOfMajorSurgeries_2  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       986 non-null    int64
#  1   Diabetes                  986 non-null    category
#  2   BloodPressureProblems     986 non-null    category
#  3   AnyTransplants            986 non-null    category
#  4   AnyChronicDiseases        986 non-null    category
#  5   Height                    986 non-null    int64
#  6   Weight                    986 non-null    float64
#  7   KnownAllergies            986 non-null    category
#  8   HistoryOfCancerInFamily   986 non-null    category
#  9   PremiumPrice              986 non-null    float64
#  10  BMI                       986 non-null    float64
#  11  NumberOfMajorSurgeries_1  986 non-null    bool
#  12  NumberOfMajorSurgeries_2  986 non-null    bool
# ...

# %%
# Convert boolean columns back to 0/1
for col in df.columns:
    if df[col].dtype == 'bool':
        df[col] = df[col].astype(int)

# Check the result
df.head()
# Out:
#    Age Diabetes BloodPressureProblems AnyTransplants AnyChronicDiseases  \
# 0   45        0                     0              0                  0
# 1   60        1                     0              0                  0
# 2   36        1                     1              0                  0
# 3   52        1                     1              0                  1
# 4   38        0                     0              0                  1
#
#    Height  Weight KnownAllergies HistoryOfCancerInFamily  PremiumPrice  \
# 0     155    57.0              0                       0       25000.0
# 1     180    73.0              0                       0       29000.0
# 2     158    59.0              0                       0       23000.0
# 3     183    93.0              0                       0       28000.0
# 4     166    88.0              0                       0       23000.0
#
#          BMI  NumberOfMajorSurgeries_1  NumberOfMajorSurgeries_2  \
# ...

# %% [markdown]
# ##  Model Selection

# %%
X = df.drop(columns=['PremiumPrice'])
y = df['PremiumPrice']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# # Linear Regression

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 14539995.139333947

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Root Mean Squared Error: 3813.134555629259

# %%
r2 = r2_score(y_test, y_pred)
print(f"R-squared: {r2}")
# Out:
# R-squared: 0.6171887390503268

# %%
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Absolute Error: 2746.4009155051317

# %% [markdown]
# ### Decision Tree

# %%
clf = tree.DecisionTreeRegressor(random_state = 42)

# %%
clf = clf.fit(X_train, y_train)

# %%
y_pred = clf.predict(X_test)

# %%
y_pred
# Out:
# array([23000., 23000., 28000., 23000., 38000., 23000., 15000., 29000.,
#        25000., 29000., 23000., 23000., 15000., 25000., 25000., 15000.,
#        23000., 29000., 16000., 28000., 15000., 28000., 23000., 15000.,
#        19000., 38000., 23000., 25000., 29000., 35000., 29000., 15000.,
#        24000., 38500., 25000., 23000., 23000., 25000., 25000., 19000.,
#        28000., 19000., 23000., 30000., 23000., 15000., 28000., 15000.,
#        29000., 28000., 15000., 21000., 15000., 28000., 30000., 28000.,
#        25000., 28000., 24000., 26000., 29000., 28000., 30000., 38500.,
#        25000., 31000., 15000., 23000., 29000., 23000., 23000., 23000.,
#        30000., 15000., 28000., 30000., 23000., 25000., 29000., 23000.,
#        30000., 28000., 15000., 29000., 23000., 28000., 32000., 23000.,
#        30000., 23000., 38000., 38000., 31000., 23000., 21000., 19000.,
#        25000., 25000., 38000., 28000., 25000., 23000., 25000., 15000.,
# ...

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared (R2): {r2:.2f}")
# Out:
# Mean Squared Error (MSE): 18111111.11
# R-squared (R2): 0.52

# %%
plt.figure(figsize=(20,10))
plot_tree(clf, feature_names=X.columns, filled=True, rounded=True, fontsize=10)
plt.show()

# %% [markdown]
# # RandomForest

# %%
rf = RandomForestRegressor(random_state = 42)

# %%
rf = rf.fit(X_train, y_train)

# %%
y_pred = rf.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared (R2): {r2:.2f}")
# Out:
# Mean Squared Error (MSE): 11110213.64
# R-squared (R2): 0.71

# %%
# Get feature importances
importances = rf.feature_importances_
features = X.columns

# Sort and plot
sorted_idx = importances.argsort()
plt.figure(figsize=(10,8))
plt.barh(features[sorted_idx], importances[sorted_idx])
plt.xlabel("Feature Importance")
plt.title("Random Forest Feature Importance")
plt.show()

# %% [markdown]
# # Grdient Boosting

# %%
# Initialize Gradient Boosting Regressor
gb_reg = GradientBoostingRegressor(
    random_state=42
)

# Train the model
gb_reg.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
y_pred = gb_reg.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared (R2): {r2:.2f}")
# Out:
# Mean Squared Error (MSE): 11842877.93
# R-squared (R2): 0.69

# %%
importances = gb_reg.feature_importances_
features = X.columns

sorted_idx = importances.argsort()
plt.figure(figsize=(10,8))
plt.barh(features[sorted_idx], importances[sorted_idx])
plt.xlabel("Feature Importance")
plt.title("Gradient Boosting Feature Importance")
plt.show()
